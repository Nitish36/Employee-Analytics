# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('datasets/HR-Employee-Attrition.csv')
dataset
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
#Data cleaning
dataset.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
dataset.dropna(inplace = True)

# %%
dataset.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
businesstravel = dataset['BusinessTravel'].value_counts()
businesstravelDF = pd.DataFrame(businesstravel)
businesstravelDF
# Out:
#                    count
# BusinessTravel
# Travel_Rarely       1043
# Travel_Frequently    277
# Non-Travel           150

# %%
businesstravel = dataset['BusinessTravel'].value_counts()

# Create the bar plot
plt.figure(figsize=(6, 5))
businesstravel.plot(kind='bar', color=['skyblue','purple','coral'])
plt.xlabel('Business Travel Frequency')
plt.ylabel('Count')
plt.title('Distribution of Business Travel')
plt.xticks(rotation=0)

# Add labels to the bars
for i, count in enumerate(businesstravel):
    plt.text(i, count + 10, str(count), ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.show()

# %%
#Descriptive Information:
#1) What is the range of ages in the dataset?
plt.hist(dataset['Age'], bins=10, edgecolor='black')

# Add labels and title
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')

# Show the plot
plt.show()

# %%
#2) How many unique values are there for each categorical variable like 'BusinessTravel', 'Department', 'EducationField', etc.?
#1)Business Travel
print("Business Travel Categorical Value")
print(dataset['BusinessTravel'].unique())
print("\n")

print("Department")
print(dataset['Department'].unique())
print("\n")

print("EducationField")
print(dataset['EducationField'].unique())
print("\n")

print("Gender")
print(dataset['Gender'].unique())
print("\n")

print("Job Role")
print(dataset['JobRole'].unique())
print("\n")

print("MaritalStatus")
print(dataset['MaritalStatus'].unique())
print("\n")

print("Over18")
print(dataset['Over18'].unique())
print("\n")

print('OverTime')
print(dataset['OverTime'].unique())
print("\n")
# Out:
# Business Travel Categorical Value
# ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
#
#
# Department
# ['Sales' 'Research & Development' 'Human Resources']
#
#
# EducationField
# ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
#
#
# Gender
# ['Female' 'Male']
#
#
# Job Role
# ['Sales Executive' 'Research Scientist' 'Laboratory Technician'
#  'Manufacturing Director' 'Healthcare Representative' 'Manager'
#  'Sales Representative' 'Research Director' 'Human Resources']
#
#
# MaritalStatus
# ['Single' 'Married' 'Divorced']
#
#
# Over18
# ['Y']
#
#
# OverTime
# ['Yes' 'No']

# %%
#Employee Demographics:
#What is the distribution of gender in the company?
gendercount = dataset['Gender'].value_counts()
gendercountDF = pd.DataFrame(gendercount)
gendercountDF
# Out:
#         count
# Gender
# Male      882
# Female    588

# %%
gender_labels = gendercountDF.index
gender_values = gendercountDF['count']

# Create a pie chart
plt.figure(figsize=(5, 5))
plt.pie(gender_values, labels=gender_labels, autopct='%1.1f%%', startangle=90, colors=['lightskyblue', 'lightcoral'])

# Title
plt.title('Gender Distribution')

# Equal aspect ratio ensures that pie is drawn as a circle
plt.axis('equal')

# Show the plot
plt.show()

# %%
#What is the average education level of employees?
ef = dataset['EducationField'].value_counts()
efdf = pd.DataFrame(ef)
efdf
# Out:
#                   count
# EducationField
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27

# %%
ef_labels = efdf.index
ef_values = efdf['count']

# Create a pie chart
plt.figure(figsize=(6, 6))
plt.pie(ef_values, labels=ef_labels, autopct='%1.1f%%', startangle=90)

# Title
plt.title('Education Field Distribution')

# Equal aspect ratio ensures that pie is drawn as a circle
plt.axis('equal')

# Show the plot
plt.show()

# %%
#Job and Satisfaction:
#What is the distribution of job roles in the company?
job = dataset['JobRole'].value_counts()
jobDF = pd.DataFrame(job)
jobDF
# Out:
#                            count
# JobRole
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52

# %%
job_labels = jobDF.index
job_values = jobDF['count']

# Create a bar graph
plt.figure(figsize=(10, 6))
plt.bar(job_labels, job_values, color=['skyblue','lightcoral','seagreen'])

# Title and labels
plt.title('Job Roles Distribution')
plt.xlabel('Job Roles')
plt.ylabel('Count')


# Rotate x-labels for better readability
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()

# %%
#How satisfied are employees with their jobs and relationships?
job_satisfaction_by_role = dataset.groupby('JobRole')['JobSatisfaction'].mean()

# Create a bar plot
plt.figure(figsize=(10, 6))
job_satisfaction_by_role.plot(kind='bar', color='skyblue')

# Title and labels
plt.title('Average Job Satisfaction by Job Role')
plt.xlabel('Job Role')
plt.ylabel('Average Job Satisfaction')

# Rotate x-labels for better readability
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()

# %%
#Work Environment
relationship_satisfaction_by_marital_status = dataset.groupby('MaritalStatus')['RelationshipSatisfaction'].mean()

# Create a bar plot
plt.figure(figsize=(7, 6))
relationship_satisfaction_by_marital_status.plot(kind='bar', color='skyblue')

# Title and labels
plt.title('Average Job Satisfaction by Job Role')
plt.xlabel('Job Role')
plt.ylabel('Average Job Satisfaction')

# Rotate x-labels for better readability
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()

# %%
#Is there a correlation between job satisfaction and performance rating?
corr_res = dataset['JobSatisfaction'].corr(dataset['PerformanceRating'])
corr_res
# Out:
# 0.0022971970637800736

# %%
#A negative correlation between job satisfaction and performance rating implies that as job satisfaction 
#increases, the performance rating tends to decrease, and vice versa.

# %%
#Career Progression:
#How long, on average, have employees been with the company?
dataset['YearsAtCompany'].mean()
# Out:
# 7.0081632653061225

# %%
#Is there a correlation between years in the current role and years since the last promotion?
corr_res = dataset['YearsInCurrentRole'].corr(dataset['YearsSinceLastPromotion'])
corr_res
# Out:
# 0.5480562476995193

# %%
#Compensation and Benefits:
plt.figure(figsize=(8, 6))
plt.hist(dataset['HourlyRate'], bins=20, color='coral', edgecolor='black')
plt.title('Distribution of Hourly Rates')
plt.xlabel('Hourly Rate')
plt.ylabel('Frequency')
plt.grid(True)
plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.hist(dataset['MonthlyIncome'], bins=20, color='purple', edgecolor='black')
plt.title('Distribution of MonthlyIncome')
plt.xlabel('Hourly Rate')
plt.ylabel('Frequency')
plt.grid(True)
plt.tight_layout()

plt.show()

# %%
#Is there a correlation between education level and salary?
corr_res = dataset['Education'].corr(dataset['MonthlyIncome'])
corr_res
# Out:
# 0.09496067704188886

# %%
#Work-Life Balance and Training:
#How many hours do employees work on average per day?
dataset['StandardHours'].mean()
# Out:
# 80.0

# %%
#How many hours of training do employees receive on average in a year?
dataset['TrainingTimesLastYear'].mean()
# Out:
# 2.7993197278911564

# %%
#Does work-life balance impact job involvement and satisfaction?
#work-life balance - job involvement
corr_res = dataset['WorkLifeBalance'].corr(dataset['JobInvolvement'])
corr_res
# Out:
# -0.014616593162761662

# %%
corr_res = dataset['WorkLifeBalance'].corr(dataset['JobSatisfaction'])
corr_res
# Out:
# -0.01945871021297395

# %%
#Marital Status and Personal Life:
#What is the marital status distribution among employees?
plt.figure(figsize=(8, 6))
plt.hist(dataset['MaritalStatus'], bins=20, color='purple', edgecolor='black')
plt.title('Distribution of MonthlyIncome')
plt.xlabel('Hourly Rate')
plt.ylabel('Frequency')
plt.grid(True)
plt.tight_layout()

plt.show()

# %%
#Stock Options and Benefits:
#How many employees have different levels of stock options?
stock = dataset.groupby('StockOptionLevel')['EmployeeNumber'].count()
stockDF = pd.DataFrame(stock)
stockDF.columns = ['Count']
stockDF
# Out:
#                   Count
# StockOptionLevel
# 0                   631
# 1                   596
# 2                   158
# 3                    85

# %%
stock = dataset.groupby('StockOptionLevel')['EmployeeNumber'].count()
stockDF = pd.DataFrame(stock)
stockDF.columns = ['Count']

# Create a bar graph
plt.figure(figsize=(5, 4))
plt.bar(stockDF.index, stockDF['Count'], color='skyblue')

# Title and labels
plt.title('Stock Option Level Distribution')
plt.xlabel('Stock Option Level')
plt.ylabel('Count')

# Show the plot
plt.tight_layout()
plt.show()

# %%
#Is there a correlation between stock option level and job level?
corr_res = dataset['StockOptionLevel'].corr(dataset['JobLevel'])
corr_res
# Out:
# 0.013983910528615499

# %%
#How does attrition vary by gender and marital status?
attritiongender = dataset.groupby('Gender')['Attrition'].value_counts()
attritiongenderDF = pd.DataFrame(attritiongender)
attritiongenderDF
# Out:
#                   count
# Gender Attrition
# Female No           501
#        Yes           87
# Male   No           732
#        Yes          150

# %%
attritiongender = dataset.groupby(['Gender', 'Attrition']).size().unstack().fillna(0)

# Create a side-by-side bar plot
ax = attritiongender.plot(kind='bar', figsize=(8, 6))

# Title and labels
plt.title('Attrition by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')

# Add labels to the bars
for container in ax.containers:
    ax.bar_label(container, label_type='edge')

# Show the plot
plt.tight_layout()
plt.show()

# %%
#Are certain departments experiencing higher attrition rates than others?
attritiondept = dataset.groupby('Department')['Attrition'].value_counts()
attritiondeptDF = pd.DataFrame(attritiondept)
attritiondeptDF
# Out:
#                                   count
# Department             Attrition
# Human Resources        No            51
#                        Yes           12
# Research & Development No           828
#                        Yes          133
# Sales                  No           354
#                        Yes           92

# %%
attritiondept = dataset.groupby(['Department', 'Attrition']).size().unstack().fillna(0)

# Create a side-by-side bar plot
ax = attritiondept.plot(kind='bar', figsize=(10, 6))

# Title and labels
plt.title('Attrition by Department')
plt.xlabel('Department')
plt.ylabel('Count')
for container in ax.containers:
    ax.bar_label(container, label_type='edge')

# Show the plot
plt.tight_layout()
plt.show()

# %%
#Does attrition vary based on work-life balance scores?
attritionwork = dataset.groupby('WorkLifeBalance')['Attrition'].value_counts()
attritionworkDF = pd.DataFrame(attritionwork)
attritionworkDF
# Out:
#                            count
# WorkLifeBalance Attrition
# 1               No            55
#                 Yes           25
# 2               No           286
#                 Yes           58
# 3               No           766
#                 Yes          127
# 4               No           126
#                 Yes           27

# %%
attrition_worklife = dataset.groupby(['WorkLifeBalance', 'Attrition']).size().unstack().fillna(0)

# Create a side-by-side bar plot
ax = attrition_worklife.plot(kind='bar', figsize=(10, 6), color=['skyblue', 'lightcoral'])

# Title and labels
plt.title('Attrition by Work Life Balance')
plt.xlabel('Work Life Balance')
plt.ylabel('Count')

# Add legend
plt.legend(title='Attrition', loc='upper right', labels=['No', 'Yes'])

# Add labels to the bars
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

# Show the plot
plt.tight_layout()
plt.show()

# %%
#Are employees with certain education fields more likely to leave the company?
attritioneducation = dataset.groupby('Education')['Attrition'].value_counts()
attritioneducationDF = pd.DataFrame(attritioneducation)
attritioneducationDF
# Out:
#                      count
# Education Attrition
# 1         No           139
#           Yes           31
# 2         No           238
#           Yes           44
# 3         No           473
#           Yes           99
# 4         No           340
#           Yes           58
# 5         No            43
#           Yes            5

# %%
attrition_education = dataset.groupby(['Education', 'Attrition']).size().unstack().fillna(0)

# Create a side-by-side bar plot
ax = attrition_education.plot(kind='bar', figsize=(10, 6), color=['skyblue', 'lightcoral'])

# Title and labels
plt.title('Attrition by Education Level')
plt.xlabel('Education Level')
plt.ylabel('Count')

# Add legend
plt.legend(title='Attrition', loc='upper right', labels=['No', 'Yes'])

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')
# Show the plot
plt.tight_layout()
plt.show()

# %%
#Is there a connection between performance ratings and attrition?
attritionperformance = dataset.groupby('PerformanceRating')['Attrition'].value_counts()
attritionperformanceDF = pd.DataFrame(attritionperformance)
attritionperformanceDF
# Out:
#                              count
# PerformanceRating Attrition
# 3                 No          1044
#                   Yes          200
# 4                 No           189
#                   Yes           37

# %%
attrition_performance = dataset.groupby(['PerformanceRating', 'Attrition']).size().unstack().fillna(0)

# Create a side-by-side bar plot
ax = attrition_performance.plot(kind='bar', figsize=(10, 6), color=['skyblue', 'lightcoral'])

# Title and labels
plt.title('Attrition by Performance Rating')
plt.xlabel('Performance Rating')
plt.ylabel('Count')

# Add legend
plt.legend(title='Attrition', loc='upper right', labels=['No', 'Yes'])

# Show the plot
plt.tight_layout()
plt.show()

# %%
#Are certain job roles associated with higher attrition rates?
attritionrole = dataset.groupby('JobRole')['Attrition'].value_counts()
attritionroleDF = pd.DataFrame(attritionrole)
attritionroleDF
# Out:
#                                      count
# JobRole                   Attrition
# Healthcare Representative No           122
#                           Yes            9
# Human Resources           No            40
#                           Yes           12
# Laboratory Technician     No           197
#                           Yes           62
# Manager                   No            97
#                           Yes            5
# Manufacturing Director    No           135
#                           Yes           10
# Research Director         No            78
#                           Yes            2
# Research Scientist        No           245
#                           Yes           47
# Sales Executive           No           269
#                           Yes           57
# Sales Representative      No            50
#                           Yes           33

# %%
attrition_role = dataset.groupby(['JobRole', 'Attrition']).size().unstack().fillna(0)

# Create a side-by-side bar plot
ax = attrition_role.plot(kind='bar', figsize=(10, 6), color=['skyblue', 'lightcoral'])

# Title and labels
plt.title('Attrition by Job Role')
plt.xlabel('Job Role')
plt.ylabel('Count')

# Add legend
plt.legend(title='Attrition', loc='upper right', labels=['No', 'Yes'])

# Rotate x-labels for better readability
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()
